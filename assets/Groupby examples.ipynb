# %%
import pandas as pd

# %%
titanic_raw_df = pd.read_csv('titanic.csv')
luistania_raw_df = pd.read_csv('lusitania.csv')

# %%
#titanic_raw_df.columns
luistania_raw_df.columns
# Out:
# Index([u'Family name', u'Title', u'Personal name', u'Fate', u'Age',
#        u'Department/Class', u'Passenger/Crew', u'Citizenship', u'Position',
#        u'Status', u'City', u'County', u'State', u'Country', u'Lifeboat',
#        u'Rescue Vessel', u'Body No.', u'Ticket No.', u'Cabin No.',
#        u'Traveling Companions and other notes', u'Value', u'Adult/Minor',
#        u'Sex'],
#       dtype='object')

# %%
titanic_raw_df.groupby(['sex','sibsp']).mean()[['age','survived']]
# Out:
#                     age  survived
# sex    sibsp
# female 0      29.349765  0.751908
#        1      30.275643  0.750000
#        2      21.558824  0.789474
#        3      17.777778  0.416667
#        4      12.571429  0.285714
#        5      13.000000  0.000000
#        8            NaN  0.000000
# male   0      31.631165  0.178060
#        1      31.840500  0.270440
#        2      25.368421  0.173913
#        3      14.428571  0.125000
#        4       7.000000  0.066667
#        5       8.750000  0.000000
#        8      14.500000  0.000000

# %%
luistania_raw_df.groupby(['Sex','Department/Class']).count()[['Fate']]
# Out:
#                                           Fate
# Sex    Department/Class
# Female Saloon                               91
#        Second                              294
#        Third                               108
#        Victualling                          25
# Male   Band                                  5
#        Deck                                 69
#        Engineering                         313
#        Saloon                              200
#        Second                              307
#        Stowaway                              3
#        Third                               262
#        Third (Distressed British Seaman)     3
#        Victualling                         281

# %%
titanic_raw_df['survived'].mean()
# Out:
# 0.3819709702062643

# %%
names_df = pd.read_csv('../../names/')

# %%
titanic_raw_df
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...
